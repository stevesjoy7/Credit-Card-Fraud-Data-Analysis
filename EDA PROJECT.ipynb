# %% [markdown]
# ### Import Required Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Dataset

# %%
df=pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# ### Analysing data

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ### Checking missing data

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of          Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 284802  False  False  False  False  False  False  False  False  False  False
# 284803  False  False  False  False  False  False  False  False  False  False
# 284804  False  False  False  False  False  False  False  False  False  False
# 284805  False  False  False  False  False  False  False  False  False  False
# ...

# %%
## Handling missing values

# %%
# Cheking percent of missing values in columns
df_missing_columns = (round(((df.isnull().sum()/len(df.index))*100),2).to_frame('null')).sort_values('null', ascending=False)
df_missing_columns
# Out:
#         null
# Time     0.0
# V16      0.0
# Amount   0.0
# V28      0.0
# V27      0.0
# V26      0.0
# V25      0.0
# V24      0.0
# V23      0.0
# V22      0.0
# V21      0.0
# V20      0.0
# V19      0.0
# V18      0.0
# V17      0.0
# V15      0.0
# V1       0.0
# V14      0.0
# V13      0.0
# V12      0.0
# V11      0.0
# V10      0.0
# V9       0.0
# V8       0.0
# V7       0.0
# V6       0.0
# V5       0.0
# V4       0.0
# V3       0.0
# V2       0.0
# Class    0.0

# %%
## Checking the distribution of the classes

# %%
classes = df['Class'].value_counts()
classes
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
nonfraud_share = round((classes[0]/df['Class'].count()*100),2)
nonfraud_share
# Out:
# 99.83

# %%
fraud_share = round((classes[1]/df['Class'].count()*100),2)
fraud_share
# Out:
# 0.17

# %% [markdown]
# ### Demonstration

# %%
class_counts = df['Class'].value_counts()

plt.figure(figsize=(8, 5))
bars = plt.bar(class_counts.index, class_counts.values, color='lightcoral')

plt.title('Count of Transactions by Class')
plt.xlabel('Class')
plt.ylabel('Number of Transactions')
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])

# Adding percentage labels on the bars
for bar, count in zip(bars, class_counts.values):
    percentage = f'{100 * count / len(df):.2f}%'
    plt.text(bar.get_x() + bar.get_width()/2 - 0.1, 
             bar.get_height() + 50, percentage, ha='center', color='black')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df_sorted = df.sort_values(by='Time')

plt.figure(figsize=(10, 5))
plt.plot(df_sorted['Time'], df_sorted['Amount'], color='purple')
plt.title('Transaction Amounts Over Time')
plt.xlabel('Time')
plt.ylabel('Transaction Amount')
plt.show()

# %% [markdown]
# ## Outliers treatment
#  We are not performing any outliers treatment for this particular dataset. Because all the outlier values are taken care while transforming the data.

# %%
## Observe the distribution of classes with time

# %%
# Creating fraudulent dataframe
data_fraud = df[df['Class'] == 1]
# Creating non fraudulent dataframe
data_non_fraud = df[df['Class'] == 0]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a distribution plot with updated functions
plt.figure(figsize=(8,5))

# Kernel Density Estimate for fraudulent transactions
sns.kdeplot(data_fraud['Time'], label='fraudulent', fill=False)

# Kernel Density Estimate for non-fraudulent transactions
sns.kdeplot(data_non_fraud['Time'], label='non fraudulent', fill=False)

# Set the labels and title of the plot
plt.xlabel('Seconds elapsed between the transaction and the first transaction')
plt.legend()
plt.show()

# %% [markdown]
# We do not see any specific pattern for the fraudulent and non-fraudulent transctions with respect to Time. Hence, we can drop the Time column.

# %%
# Dropping the Time column
df.drop('Time', axis=1, inplace=True)

# %% [markdown]
# ## Observe the distribution of classes with amount

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a distribution plot with updated functions
plt.figure(figsize=(8, 5))

# Kernel Density Estimate for fraudulent transaction amounts
sns.kdeplot(data_fraud['Amount'], label='fraudulent', fill=False)

# Kernel Density Estimate for non-fraudulent transaction amounts
sns.kdeplot(data_non_fraud['Amount'], label='non fraudulent', fill=False)

# Set the labels and title of the plot
plt.xlabel('Transaction Amount')
plt.legend()
plt.show()

# %% [markdown]
# We can see that the fraudulent transctions are mostly densed in the lower range of amount, whereas the non-fraudulent transctions are spreaded throughout low to high range of amount.

# %% [markdown]
# ## Feature Scaling
# We need to scale only the Amount column

# %%
# Standardization method
from sklearn.preprocessing import StandardScaler

# %%
# Instantiate the Scaler
scaler = StandardScaler()

# %%
# Import library
from sklearn.model_selection import train_test_split

# %%
# Putting feature variables into X
X = df.drop(['Class'], axis=1)

# %%
# Putting target variable to y
y = df['Class']

# %%
# Splitting data into train and test set 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)

# %%
# Fit the data into scaler and transform
X_train['Amount'] = scaler.fit_transform(X_train[['Amount']])
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 201788  2.023734 -0.429219 -0.691061 -0.201461 -0.162486  0.283718 -0.674694
# 179369 -0.145286  0.736735  0.543226  0.892662  0.350846  0.089253  0.626708
# 73138  -3.015846 -1.920606  1.229574  0.721577  1.089918 -0.195727 -0.462586
# 208679  1.851980 -1.007445 -1.499762 -0.220770 -0.568376 -1.232633  0.248573
# 206534  2.237844 -0.551513 -1.426515 -0.924369 -0.401734 -1.438232 -0.119942
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 201788  0.192230  1.124319 -0.037763  ... -0.171390 -0.195207 -0.477813
# 179369 -0.049137 -0.732566  0.297692  ...  0.206709 -0.124288 -0.263560
# 73138   0.919341 -0.612193 -0.966197  ...  0.842838  0.274911 -0.319550
# 208679 -0.539483 -0.813368  0.785431  ... -0.196551 -0.406722 -0.899081
# 206534 -0.449263 -0.717258  0.851668  ... -0.045417  0.050447  0.125601
#
# ...

# %% [markdown]
# ## Checking the Skewness

# %%
# Listing the columns
cols = X_train.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
#       dtype='object')

# %%
# Columns to keep
target_columns = [ 'V1', 'V2', 'V3', 'V4', 'V5', 'Amount', 'Class']

# Create a new DataFrame with the selected columns
cc_data = df[target_columns]
cc_data.head()
# Out:
#          V1        V2        V3        V4        V5  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  0.060018    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193   69.99      0

# %%
# Define the columns you want to plot
columns_to_plot = ['V1', 'V2', 'V3', 'V4', 'V5', 'Amount']

# Create subplots for the histograms
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.subplots_adjust(hspace=0.5)

for i, col in enumerate(columns_to_plot):
    row_idx = i // 3
    col_idx = i % 3

    sns.histplot(data=cc_data, x=col, kde=True, color='blue', ax=axes[row_idx, col_idx])
    axes[row_idx, col_idx].set_title(f'Histogram of {col}')
    axes[row_idx, col_idx].set_xlabel(col)
    axes[row_idx, col_idx].set_ylabel('Frequency')

# Remove empty subplots, if any
for i in range(len(columns_to_plot), 2 * 3):
    fig.delaxes(axes.flatten()[i])

plt.show()

# %% [markdown]
# ## Univariate Analysis: Distribution of Classes

# %%
# Check class distribution
sns.countplot(x='Class', data=df, palette='coolwarm')
plt.title('Distribution of Classes (Fraud vs Non-Fraud)')
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])
plt.show()

# %% [markdown]
# ## Bivariate Analysis: Correlation Heatmap

# %%
# Compute correlation matrix
corr = df.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr, cmap='coolwarm', annot=False)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Bivariate Analysis: Box Plot of a Feature vs Class

# %%
# Box plot for V1 and Class
sns.boxplot(x='Class', y='V1', data=df, palette='Set2')
plt.title('Box Plot of V1 vs Class')
plt.xticks([0, 1], ['Non-Fraud', 'Fraud'])
plt.show()

# %% [markdown]
# ## Multivariate Analysis: Pair Plot

# %%
# Pair plot of selected features 
#(V1, V2, V3, V4, V5 and Class)
sns.pairplot(df[['V1', 'V2', 'V3', 'V4', 'V5', 'Class']],
             hue='Class', palette='husl')
plt.show()

# %% [markdown]
# ## Time vs Fraud Analysis

# %%
# Line plot for transaction time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Time', y='Amount', hue='Class', data=df, palette='Set1')
plt.title('Transaction Amount vs Time')
plt.show()
